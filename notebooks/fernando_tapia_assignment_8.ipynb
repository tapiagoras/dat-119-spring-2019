# %% [markdown]
# # Assignment # 8
#
# 1. Program that creates a To-Do list application.
#
# ### Planning Doc
#
#
# I will use at least two lists to hold the information for the to-do and the completed section.
#
# todo_list
# completed_list
#
# A while loop to keep the user navigating in the main interface
#
#     - inside the loop there will be a call to 3 different functions depending on the user input:
#
# 	1. view_todo_completed(list): this will display the todo_list or completed_list using a for range loop
#         if empty
#             display message to user
#         else
#             display list
#
#         - I will need input validation (This will be another function)
#
#         - As a parameter will receive the list to be displayed
#
#     2. add_item(): this function will ask the user for an item to include in the todo_list
#
#         input user inside a while loop to add multiple items at the same time and validate user_input<br>
#
#         display err messages base on input
#
# 	3. mark_as_completed: this function will ask the user for the number of the item to be removed and remove from the todo_list and added to te completed_list <br>
#
# All validation will be based on the list_lentgh
#
# Some code for the completed part:
#
# aux=todo_list[n-1]<br>
# todo_list.remove(aux)<br>
# completed_list.append(aux)<br>
#
# ### Code

# %%
'''

 Fernando Tapia Tinoco 
 3/27/2019
 Python 1 - DAT-119 - Spring 2019
 In-class Assignment # 8
     Program that handle a TO-DO list.

'''
#function that display a list content
# message: print the title previous to the list
# selected_list: list to be displayed
# wait_for_user: add the enter option at the end to make a pause
def view_list(message,selected_list,wait_for_user):
    print(message)
    if len(selected_list):
        #loop to display the list items
        for item in range(len(selected_list)):
            print(item+1,") ",selected_list[item],sep="")
       
    else:
        print("There is nothing to display.")
        
    # pause until user hits enter
    if(wait_for_user):
        print("")
        input("Hit enter when finished viewing ")
        print("")
#function that add an item to the list    
def add_todo_list(todo_list):
    new_item = input("What would you like to add? ")
    if new_item not in todo_list:
        todo_list.append(new_item)
    else:
        
        user_input = input ("This option is already in the list. Do you want to add this item anyway Y/N: ")
        if ("Y" in user_input or "y" in user_input):
            todo_list.append(new_item)
        else :     
            print(new_item, "won't be added.")

#function to remove an item from the list
def complete_task(todo_list,completed_list):
    #print the items availables on todo_list
    view_list("Choose an item to mark completed. ",todo_list,False)
    if (len(todo_list)>0):#validate that the todo list has at least one item
        user_selection = validate_selection(todo_list) #validates the user selection
        #the following line storage the value of the user_selection for future usage
        user_selection_item = todo_list[user_selection-1] 
        todo_list.remove(user_selection_item)
        completed_list.append(user_selection_item)
    return completed_list
    
#Function to validate the user input based on the number of available options
def validate_selection(list_to_evaluate):
    user_selection = 0
    input_wrong = True
    print("")
    while user_selection < 1 or user_selection > len(list_to_evaluate):
        while input_wrong:
            user_selection = input("Please choose one of the options above: ")
            if user_selection.isdigit():
                if(int(user_selection) > len(list_to_evaluate)):
                    input_wrong = True
                else:
                    user_selection = int (user_selection)
                    input_wrong = False
            else:
                input_wrong = True
    print("")
    return user_selection

        
def main():
    
    #define lists
    menu_list = ("View the items on your todo list","View the items you have finished",
             "Add an item to the todo list","Mark a todo list item as completed",
            "Exit the Todo List Application (your list will not be saved)")
    todo_list = []
    completed_list = []
   
    print("Welcome to the Todo List Application.")
    
    app_is_running = True
    
    
    #Loop to keep the app running
    while (app_is_running):
        view_list ("",menu_list,False)
        user_selection = validate_selection(menu_list)
        if user_selection == 1:
            view_list ("This is your todo list: ",todo_list,True)
        elif user_selection == 2:
            view_list ("This is your list of completed tasks: ",completed_list,True)
        elif user_selection == 3:
            add_todo_list(todo_list)
        elif user_selection == 4:
            completed_list = complete_task(todo_list,completed_list)
        if user_selection == 5:
            app_is_running = False
            print("Thank you for using the To-Do List Application.")

if __name__ == "__main__":
	main()
# Out:
# Welcome to the Todo List Application.
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 1
#
# This is your todo list:
# There is nothing to display.
#
# Hit enter when finished viewing 2
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above:
# Please choose one of the options above: 2
#
# This is your list of completed tasks:
# There is nothing to display.
#
# Hit enter when finished viewing
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 3
#
# What would you like to add? Sleep
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 3
#
# What would you like to add? Finish Python asignment
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 3
#
# What would you like to add? Seriously FINISH! Python asignment
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 2
#
# This is your list of completed tasks:
# There is nothing to display.
#
# Hit enter when finished viewing 1
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 1
#
# This is your todo list:
# 1) Sleep
# 2) Finish Python asignment
# 3) Seriously FINISH! Python asignment
#
# Hit enter when finished viewing
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 4
#
# Choose an item to mark completed.
# 1) Sleep
# 2) Finish Python asignment
# 3) Seriously FINISH! Python asignment
#
# Please choose one of the options above: 3
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 2
#
# This is your list of completed tasks:
# 1) Seriously FINISH! Python asignment
#
# Hit enter when finished viewing
#
#
# 1) View the items on your todo list
# 2) View the items you have finished
# 3) Add an item to the todo list
# 4) Mark a todo list item as completed
# 5) Exit the Todo List Application (your list will not be saved)
#
# Please choose one of the options above: 5
#
# Thank you for using the To-Do List Application.

# %% [markdown]
# ### Final Thoughts
#
# The project is done. I added the part to check if the user wants to duplicate a todo item. And now is working as expected.

# %% [markdown]
# 2. Short Answer questions:
#     - Describe the three steps that must be taken when a file is used by a program.
#         > Open a file.- we can use this to create a connection between the file and the program or create a file to write on it, or open a file just with read access.
#     - Why should a program close a file when it’s finished using it?
#         > Because finishing the program without closing the file may cause losing of data.
#     - What is a file’s read position? Where is the read position when a file is first opened for reading?
#         > A file’s read position marks the location of the next item that will be read from the file. Initially, the read position is set to the beginning of the file.
#     - If an existing file is opened in append mode, what happens to the file’s existing contents?
#         > The content remains the same and new content is added to the end of the file.
