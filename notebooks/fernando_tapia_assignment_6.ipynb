# %% [markdown]
# # Assignment # 6
#
# 1. Short Answer questions:
#     - Look at the following statement:
#         > numbers = [10, 20, 30, 40, 50]
#             1. How many elements does the list have? 5
#             2. What is the index of the first element in the list? 0
#             3. What is the index of the last element in the list? 4
#     - Look at the following statement:
#         > numbers = [1, 2, 3]
#             1. What value is stored in numbers[2]? 3
#             2. What value is stored in numbers[0]? 1
#             3. What value is stored in numbers[−1]? 3
#     - What will the following code display?
#         > values = [2, 4, 6, 8, 10]
#             print(values[1:3]) 4,6
#     - What does the following code display?
#         > numbers = [1, 2, 3, 4, 5, 6, 7]
#             print(numbers[5:]) 6,7
#
# ***
# 2. Write a random number guessing game!
#     - Your program should generate a random number in the range from 1 through 100 and ask the user to guess what the number is. If they guess too high, the program should display “Too high, try again.” If they guess too low, the program should display “Too low, try again.” If they guess the correct number, the application should congratulate them, tell them how many guesses it took, and ask if they want to play again. If they do, the program should generate a new random number and let them play again. (We did functions this week, so I'm going to expect to see you use those.)
#
# ## Pseudocode
#
#     1. Define a function that compares a random number with the user input print a message and return a boolean value
#     2. Generate a random number
#     3. Inside a loop Ask the user for input until match with the random number
#     4. Inside the loop add a counter variable
#     5. Display number of tries
#     6. ask the user if want to play again

# %%
'''

 Fernando Tapia Tinoco 
 3/20/2019
 Python 1 - DAT-119 - Spring 2019
 Assignment # 6
     program that asks the user to guest a random number.

'''
#imports
import random

#functions
# This function receive the random number and also the input from the user to evaluate which
# one is higher and return a boolean number if only return false when the number is a match.
def compare_random_input(computer, human):
        if (computer > human):
            print("Too low, try again.")
            return False
        elif(computer < human):
            print("Too high, try again.")
            return False
        else:
            return True

# This function star the game generates a random number and initialize the loop 
# to compare both values random and user input      
def guessing_game(computer):
    match = False #this variable store the Boolean value when evaluating if both values are equal
    count = 0 #try counter
    while (not match):
        count = count + 1
        human = input("Try to guess my number: ")
        match = compare_random_input(int(computer), int(human))
    #Display results
    print("")
    print("Congratulations (ง°ل͜°)ง, it only took you",count,"tries")
    print("")
    return match

# here we define our main code block
def main():
    
    play = True #artifice to avoid an input outside the loop
    #Loop for playing multiple times
    while (play):
        print("Welcome to Guess a number Game (?)")
        print("¯\_(ツ)_/¯")
        print("")
        #The next line generates a random number from 0 to 100, taking the whole part 
        #of the random floating number multiplied by 100
        computer = int(random.random() * 100) 
        #print (computer) #for evaluation purpose
        if (guessing_game(computer)):
            #Evaluation to play again
            play = input("DO you want to play again (Y/N): ")
            if ("y" in play or "Y" in play):
                play = True
            else :
                print("See you next time")
                play = False
        
    
# and we run it with this incantation
if __name__ == "__main__":
    main()
# Out:
# Welcome to Guess a number Game (?)
# ¯\_(ツ)_/¯
#
# Try to guess my number: 20
# Too low, try again.
# Try to guess my number: 40
# Too low, try again.
# Try to guess my number: 50
# Too low, try again.
# Try to guess my number: 90
# Too high, try again.
# Try to guess my number: 70
#
# Congratulations (ง°ل͜°)ง, it only took you 5 tries
